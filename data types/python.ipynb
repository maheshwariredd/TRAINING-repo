# %% [markdown]
# list is a mutable which is change and it  allow dublicates
#
# > Add blockquote

# %%
List = [1,2,3,4,5]
print(List)
# Out:
# [1, 2, 3, 4, 5]

# %%
List = ["mahi","akhil", "eshwar","srija","srija","mahi"]
print(List)
print(len(List))
List.count("mahi") # it showes how many mahi's are here in the list
List.append("Kavya")
# Out:
# ['mahi', 'akhil', 'eshwar', 'srija', 'srija', 'mahi']
# 6

# %% [markdown]
# Tuple = A tuple is an ordered, immutable collection it allow duplicates

# %%
t = (1,2,3,3,3)
print(t)
t.count(3)
# Out:
# (1, 2, 3, 3, 3)
# 3

# %% [markdown]
# A dictionary stores key-value pairs.

# %%
student = {
      "name": "mahi",
          "age": 22
}

# %% [markdown]
# set is an unordered collection of unique elements.

# %%
s = {1,2,3,3,4}
print(s)
#it remove duplicants
s.add(5)
print(s)
# Out:
# {1, 2, 3, 4}
# {1, 2, 3, 4, 5}

# %%
#union
a = {1,2,3}
b= {3,4,5}
print(a|b)
#intersection
print(a&b) # it prints only common element in the both the set
#difference
print(a-b) # it remove common element from a to b
print(b-a)# it remove common element from b to a
# symmetric difference
print(a^b) # it remove common element from both the set and print remaining elements
# Out:
# {1, 2, 3, 4, 5}
# {3}
# {1, 2}
# {4, 5}
# {1, 2, 4, 5}
